# %%
import pandas as pd
from sklearn.model_selection import train_test_split

from gridsearch_utils import *

# %%
import IPython

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df_labeled = pd.read_csv("labeled_examples.csv")
df_unlabeled = pd.read_csv("unlabeled_sample01_cellpose.csv")

# we remove the centroid displacement features as they're bugged (for now)
del df_labeled['PhaseSTDLocalCentroidDisplacement']
del df_unlabeled['PhaseSTDLocalCentroidDisplacement']
del df_labeled['AmplitudeSTDLocalCentroidDisplacement']
del df_unlabeled['AmplitudeSTDLocalCentroidDisplacement']

df_labeled['Labels'] = df_labeled['Labels'].str.strip("b'")

X = df_labeled.drop("Labels", axis=1)
y = df_labeled['Labels']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, 
                                                    random_state=22, stratify=y)

# %%
ct = create_column_transformer(X, y)

# %% [markdown]
# # OOF Binary Classifier

# %%
y_train_binary_oof = np.where(y_train == 'oof', 1, 0)
y_test_binary_oof = np.where(y_test == 'oof', 1, 0)

# %% [markdown]
# ## Logistic Regression

# %%
oof_logreg_prauc = binary_logreg_gridsearch(ct, X_train, y_train_binary_oof, 'AVG_PR')
oof_logreg_prauc_model = oof_logreg_prauc.best_estimator_
save_model(oof_logreg_prauc_model, "models", "oof_logreg_prauc.pkl")

oof_logreg_fhalf = binary_logreg_gridsearch(ct, X_train, y_train_binary_oof, 'FHALF')
oof_logreg_fhalf_model = oof_logreg_fhalf.best_estimator_
save_model(oof_logreg_fhalf_model, "models", "oof_logreg_fhalf.pkl")

evaluate_model(oof_logreg_prauc_model, X_train, X_test, y_train_binary_oof, y_test_binary_oof)
evaluate_model(oof_logreg_fhalf_model, X_train, X_test, y_train_binary_oof, y_test_binary_oof)
# Out:
# Fitting 25 folds for each of 1080 candidates, totalling 27000 fits
# [CV 1/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=5, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=None, undersample=RandomUnderSampler(random_state=42); ACC: (train=0.091, test=0.118) AVG_PR: (train=0.091, test=0.118) BACC: (train=0.500, test=0.500) F1: (train=0.167, test=0.211) FHALF: (train=0.111, test=0.143) RE: (train=1.000, test=1.000) total time=   0.1s
# [CV 17/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=5, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=None, undersample=RandomUnderSampler(random_state=42); ACC: (train=0.091, test=0.118) AVG_PR: (train=0.091, test=0.118) BACC: (train=0.500, test=0.500) F1: (train=0.167, test=0.211) FHALF: (train=0.111, test=0.143) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 19/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=5, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=None, undersample=RandomUnderSampler(random_state=42); ACC: (train=0.104, test=0.062) AVG_PR: (train=0.104, test=0.062) BACC: (train=0.500, test=0.500) F1: (train=0.189, test=0.118) FHALF: (train=0.127, test=0.077) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 24/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=5, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=None, undersample=RandomUnderSampler(random_state=42); ACC: (train=0.104, test=0.062) AVG_PR: (train=0.104, test=0.062) BACC: (train=0.500, test=0.500) F1: (train=0.189, test=0.118) FHALF: (train=0.127, test=0.077) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 4/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=5, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=StandardScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.104, test=0.062) AVG_PR: (train=0.104, test=0.062) BACC: (train=0.500, test=0.500) F1: (train=0.189, test=0.118) FHALF: (train=0.127, test=0.077) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 13/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=5, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=StandardScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.091, test=0.118) AVG_PR: (train=0.091, test=0.118) BACC: (train=0.500, test=0.500) F1: (train=0.167, test=0.211) FHALF: (train=0.111, test=0.143) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 25/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=5, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=StandardScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.104, test=0.062) AVG_PR: (train=0.104, test=0.062) BACC: (train=0.500, test=0.500) F1: (train=0.189, test=0.118) FHALF: (train=0.127, test=0.077) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 16/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=5, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=MinMaxScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.909, test=0.882) AVG_PR: (train=0.091, test=0.118) BACC: (train=0.500, test=0.500) F1: (train=0.000, test=0.000) FHALF: (train=0.000, test=0.000) RE: (train=0.000, test=0.000) total time=   0.0s
# [CV 7/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=10, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=None, undersample=RandomUnderSampler(random_state=42); ACC: (train=0.091, test=0.118) AVG_PR: (train=0.091, test=0.118) BACC: (train=0.500, test=0.500) F1: (train=0.167, test=0.211) FHALF: (train=0.111, test=0.143) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 22/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=10, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=None, undersample=RandomUnderSampler(random_state=42); ACC: (train=0.091, test=0.118) AVG_PR: (train=0.091, test=0.118) BACC: (train=0.500, test=0.500) F1: (train=0.167, test=0.211) FHALF: (train=0.111, test=0.143) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 13/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=10, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=StandardScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.091, test=0.118) AVG_PR: (train=0.091, test=0.118) BACC: (train=0.500, test=0.500) F1: (train=0.167, test=0.211) FHALF: (train=0.111, test=0.143) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 4/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=10, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=MinMaxScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.896, test=0.938) AVG_PR: (train=0.104, test=0.062) BACC: (train=0.500, test=0.500) F1: (train=0.000, test=0.000) FHALF: (train=0.000, test=0.000) RE: (train=0.000, test=0.000) total time=   0.0s
# [CV 20/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=10, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=MinMaxScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.896, test=0.938) AVG_PR: (train=0.104, test=0.062) BACC: (train=0.500, test=0.500) F1: (train=0.000, test=0.000) FHALF: (train=0.000, test=0.000) RE: (train=0.000, test=0.000) total time=   0.0s
# [CV 11/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=15, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=None, undersample=RandomUnderSampler(random_state=42); ACC: (train=0.909, test=0.882) AVG_PR: (train=0.274, test=0.583) BACC: (train=0.500, test=0.500) F1: (train=0.000, test=0.000) FHALF: (train=0.000, test=0.000) RE: (train=0.000, test=0.000) total time=   0.0s
# [CV 4/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=15, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=StandardScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.104, test=0.062) AVG_PR: (train=0.104, test=0.062) BACC: (train=0.500, test=0.500) F1: (train=0.189, test=0.118) FHALF: (train=0.127, test=0.077) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 21/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=15, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=StandardScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.091, test=0.118) AVG_PR: (train=0.091, test=0.118) BACC: (train=0.500, test=0.500) F1: (train=0.167, test=0.211) FHALF: (train=0.111, test=0.143) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 11/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=15, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=MinMaxScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.909, test=0.882) AVG_PR: (train=0.091, test=0.118) BACC: (train=0.500, test=0.500) F1: (train=0.000, test=0.000) FHALF: (train=0.000, test=0.000) RE: (train=0.000, test=0.000) total time=   0.0s
# [CV 2/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=5, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=None, undersample=RandomUnderSampler(random_state=42); ACC: (train=0.091, test=0.118) AVG_PR: (train=0.091, test=0.118) BACC: (train=0.500, test=0.500) F1: (train=0.167, test=0.211) FHALF: (train=0.111, test=0.143) RE: (train=1.000, test=1.000) total time=   0.1s
# [CV 18/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=5, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=None, undersample=RandomUnderSampler(random_state=42); ACC: (train=0.091, test=0.118) AVG_PR: (train=0.091, test=0.118) BACC: (train=0.500, test=0.500) F1: (train=0.167, test=0.211) FHALF: (train=0.111, test=0.143) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 21/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=5, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=None, undersample=RandomUnderSampler(random_state=42); ACC: (train=0.091, test=0.118) AVG_PR: (train=0.091, test=0.118) BACC: (train=0.500, test=0.500) F1: (train=0.167, test=0.211) FHALF: (train=0.111, test=0.143) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 3/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=5, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=StandardScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.091, test=0.118) AVG_PR: (train=0.091, test=0.118) BACC: (train=0.500, test=0.500) F1: (train=0.167, test=0.211) FHALF: (train=0.111, test=0.143) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 14/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=5, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=StandardScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.104, test=0.062) AVG_PR: (train=0.104, test=0.062) BACC: (train=0.500, test=0.500) F1: (train=0.189, test=0.118) FHALF: (train=0.127, test=0.077) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 3/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=5, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=MinMaxScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.909, test=0.882) AVG_PR: (train=0.091, test=0.118) BACC: (train=0.500, test=0.500) F1: (train=0.000, test=0.000) FHALF: (train=0.000, test=0.000) RE: (train=0.000, test=0.000) total time=   0.0s
# [CV 19/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=5, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=MinMaxScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.896, test=0.938) AVG_PR: (train=0.104, test=0.062) BACC: (train=0.500, test=0.500) F1: (train=0.000, test=0.000) FHALF: (train=0.000, test=0.000) RE: (train=0.000, test=0.000) total time=   0.0s
# [CV 9/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=10, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=None, undersample=RandomUnderSampler(random_state=42); ACC: (train=0.104, test=0.062) AVG_PR: (train=0.104, test=0.062) BACC: (train=0.500, test=0.500) F1: (train=0.189, test=0.118) FHALF: (train=0.127, test=0.077) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 23/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=10, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=None, undersample=RandomUnderSampler(random_state=42); ACC: (train=0.091, test=0.118) AVG_PR: (train=0.091, test=0.118) BACC: (train=0.500, test=0.500) F1: (train=0.167, test=0.211) FHALF: (train=0.111, test=0.143) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 14/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=10, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=StandardScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.104, test=0.062) AVG_PR: (train=0.104, test=0.062) BACC: (train=0.500, test=0.500) F1: (train=0.189, test=0.118) FHALF: (train=0.127, test=0.077) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 5/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=10, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=MinMaxScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.896, test=0.938) AVG_PR: (train=0.104, test=0.062) BACC: (train=0.500, test=0.500) F1: (train=0.000, test=0.000) FHALF: (train=0.000, test=0.000) RE: (train=0.000, test=0.000) total time=   0.0s
# [CV 22/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=10, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=MinMaxScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.909, test=0.882) AVG_PR: (train=0.091, test=0.118) BACC: (train=0.500, test=0.500) F1: (train=0.000, test=0.000) FHALF: (train=0.000, test=0.000) RE: (train=0.000, test=0.000) total time=   0.0s
# [CV 14/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=15, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=None, undersample=RandomUnderSampler(random_state=42); ACC: (train=0.104, test=0.062) AVG_PR: (train=0.104, test=0.062) BACC: (train=0.500, test=0.500) F1: (train=0.189, test=0.118) FHALF: (train=0.127, test=0.077) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 6/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=15, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=StandardScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.091, test=0.118) AVG_PR: (train=0.091, test=0.118) BACC: (train=0.500, test=0.500) F1: (train=0.167, test=0.211) FHALF: (train=0.111, test=0.143) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 22/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=15, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=StandardScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.091, test=0.118) AVG_PR: (train=0.091, test=0.118) BACC: (train=0.500, test=0.500) F1: (train=0.167, test=0.211) FHALF: (train=0.111, test=0.143) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 13/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=15, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=MinMaxScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.909, test=0.882) AVG_PR: (train=0.091, test=0.118) BACC: (train=0.500, test=0.500) F1: (train=0.000, test=0.000) FHALF: (train=0.000, test=0.000) RE: (train=0.000, test=0.000) total time=   0.0s
# [CV 4/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=all, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=None, undersample=RandomUnderSampler(random_state=42); ACC: (train=0.896, test=0.938) AVG_PR: (train=0.283, test=0.500) BACC: (train=0.500, test=0.500) F1: (train=0.000, test=0.000) FHALF: (train=0.000, test=0.000) RE: (train=0.000, test=0.000) total time=   0.0s
# [CV 4/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=5, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=None, undersample=RandomUnderSampler(random_state=42); ACC: (train=0.104, test=0.062) AVG_PR: (train=0.104, test=0.062) BACC: (train=0.500, test=0.500) F1: (train=0.189, test=0.118) FHALF: (train=0.127, test=0.077) RE: (train=1.000, test=1.000) total time=   0.1s
# [CV 20/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=5, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=None, undersample=RandomUnderSampler(random_state=42); ACC: (train=0.104, test=0.062) AVG_PR: (train=0.104, test=0.062) BACC: (train=0.500, test=0.500) F1: (train=0.189, test=0.118) FHALF: (train=0.127, test=0.077) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 25/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=5, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=None, undersample=RandomUnderSampler(random_state=42); ACC: (train=0.104, test=0.062) AVG_PR: (train=0.104, test=0.062) BACC: (train=0.500, test=0.500) F1: (train=0.189, test=0.118) FHALF: (train=0.127, test=0.077) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 6/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=5, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=StandardScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.091, test=0.118) AVG_PR: (train=0.091, test=0.118) BACC: (train=0.500, test=0.500) F1: (train=0.167, test=0.211) FHALF: (train=0.111, test=0.143) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 16/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=5, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=StandardScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.091, test=0.118) AVG_PR: (train=0.091, test=0.118) BACC: (train=0.500, test=0.500) F1: (train=0.167, test=0.211) FHALF: (train=0.111, test=0.143) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 7/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=5, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=MinMaxScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.909, test=0.882) AVG_PR: (train=0.091, test=0.118) BACC: (train=0.500, test=0.500) F1: (train=0.000, test=0.000) FHALF: (train=0.000, test=0.000) RE: (train=0.000, test=0.000) total time=   0.0s
# [CV 24/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=5, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=MinMaxScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.896, test=0.938) AVG_PR: (train=0.104, test=0.062) BACC: (train=0.500, test=0.500) F1: (train=0.000, test=0.000) FHALF: (train=0.000, test=0.000) RE: (train=0.000, test=0.000) total time=   0.0s
# [CV 14/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=10, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=None, undersample=RandomUnderSampler(random_state=42); ACC: (train=0.104, test=0.062) AVG_PR: (train=0.104, test=0.062) BACC: (train=0.500, test=0.500) F1: (train=0.189, test=0.118) FHALF: (train=0.127, test=0.077) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 5/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=10, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=StandardScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.104, test=0.062) AVG_PR: (train=0.104, test=0.062) BACC: (train=0.500, test=0.500) F1: (train=0.189, test=0.118) FHALF: (train=0.127, test=0.077) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 20/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=10, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=StandardScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.104, test=0.062) AVG_PR: (train=0.104, test=0.062) BACC: (train=0.500, test=0.500) F1: (train=0.189, test=0.118) FHALF: (train=0.127, test=0.077) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 9/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=10, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=MinMaxScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.896, test=0.938) AVG_PR: (train=0.104, test=0.062) BACC: (train=0.500, test=0.500) F1: (train=0.000, test=0.000) FHALF: (train=0.000, test=0.000) RE: (train=0.000, test=0.000) total time=   0.0s
# [CV 2/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=15, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=None, undersample=RandomUnderSampler(random_state=42); ACC: (train=0.091, test=0.118) AVG_PR: (train=0.091, test=0.118) BACC: (train=0.500, test=0.500) F1: (train=0.167, test=0.211) FHALF: (train=0.111, test=0.143) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 19/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=15, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=None, undersample=RandomUnderSampler(random_state=42); ACC: (train=0.104, test=0.062) AVG_PR: (train=0.104, test=0.062) BACC: (train=0.500, test=0.500) F1: (train=0.189, test=0.118) FHALF: (train=0.127, test=0.077) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 11/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=15, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=StandardScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.091, test=0.118) AVG_PR: (train=0.091, test=0.118) BACC: (train=0.500, test=0.500) F1: (train=0.167, test=0.211) FHALF: (train=0.111, test=0.143) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 2/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=15, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=MinMaxScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.909, test=0.882) AVG_PR: (train=0.091, test=0.118) BACC: (train=0.500, test=0.500) F1: (train=0.000, test=0.000) FHALF: (train=0.000, test=0.000) RE: (train=0.000, test=0.000) total time=   0.0s
# [CV 18/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=15, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=MinMaxScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.909, test=0.882) AVG_PR: (train=0.091, test=0.118) BACC: (train=0.500, test=0.500) F1: (train=0.000, test=0.000) FHALF: (train=0.000, test=0.000) RE: (train=0.000, test=0.000) total time=   0.0s
# [CV 9/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=all, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=None, undersample=RandomUnderSampler(random_state=42); ACC: (train=0.896, test=0.938) AVG_PR: (train=0.306, test=0.250) BACC: (train=0.500, test=0.500) F1: (train=0.000, test=0.000) FHALF: (train=0.000, test=0.000) RE: (train=0.000, test=0.000) total time=   0.0s
# [CV 3/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=5, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=None, undersample=RandomUnderSampler(random_state=42); ACC: (train=0.091, test=0.118) AVG_PR: (train=0.091, test=0.118) BACC: (train=0.500, test=0.500) F1: (train=0.167, test=0.211) FHALF: (train=0.111, test=0.143) RE: (train=1.000, test=1.000) total time=   0.1s
# [CV 23/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=5, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=None, undersample=RandomUnderSampler(random_state=42); ACC: (train=0.091, test=0.118) AVG_PR: (train=0.091, test=0.118) BACC: (train=0.500, test=0.500) F1: (train=0.167, test=0.211) FHALF: (train=0.111, test=0.143) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 1/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=5, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=StandardScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.091, test=0.118) AVG_PR: (train=0.091, test=0.118) BACC: (train=0.500, test=0.500) F1: (train=0.167, test=0.211) FHALF: (train=0.111, test=0.143) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 7/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=5, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=StandardScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.091, test=0.118) AVG_PR: (train=0.091, test=0.118) BACC: (train=0.500, test=0.500) F1: (train=0.167, test=0.211) FHALF: (train=0.111, test=0.143) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 20/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=5, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=StandardScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.104, test=0.062) AVG_PR: (train=0.104, test=0.062) BACC: (train=0.500, test=0.500) F1: (train=0.189, test=0.118) FHALF: (train=0.127, test=0.077) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 12/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=5, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=MinMaxScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.909, test=0.882) AVG_PR: (train=0.091, test=0.118) BACC: (train=0.500, test=0.500) F1: (train=0.000, test=0.000) FHALF: (train=0.000, test=0.000) RE: (train=0.000, test=0.000) total time=   0.0s
# [CV 4/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=10, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=None, undersample=RandomUnderSampler(random_state=42); ACC: (train=0.104, test=0.062) AVG_PR: (train=0.104, test=0.062) BACC: (train=0.500, test=0.500) F1: (train=0.189, test=0.118) FHALF: (train=0.127, test=0.077) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 20/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=10, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=None, undersample=RandomUnderSampler(random_state=42); ACC: (train=0.104, test=0.062) AVG_PR: (train=0.104, test=0.062) BACC: (train=0.500, test=0.500) F1: (train=0.189, test=0.118) FHALF: (train=0.127, test=0.077) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 11/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=10, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=StandardScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.091, test=0.118) AVG_PR: (train=0.091, test=0.118) BACC: (train=0.500, test=0.500) F1: (train=0.167, test=0.211) FHALF: (train=0.111, test=0.143) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 25/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=10, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=StandardScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.104, test=0.062) AVG_PR: (train=0.104, test=0.062) BACC: (train=0.500, test=0.500) F1: (train=0.189, test=0.118) FHALF: (train=0.127, test=0.077) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 16/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=10, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=MinMaxScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.909, test=0.882) AVG_PR: (train=0.091, test=0.118) BACC: (train=0.500, test=0.500) F1: (train=0.000, test=0.000) FHALF: (train=0.000, test=0.000) RE: (train=0.000, test=0.000) total time=   0.0s
# [CV 6/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=15, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=None, undersample=RandomUnderSampler(random_state=42); ACC: (train=0.091, test=0.118) AVG_PR: (train=0.091, test=0.118) BACC: (train=0.500, test=0.500) F1: (train=0.167, test=0.211) FHALF: (train=0.111, test=0.143) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 22/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=15, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=None, undersample=RandomUnderSampler(random_state=42); ACC: (train=0.909, test=0.882) AVG_PR: (train=0.285, test=0.333) BACC: (train=0.500, test=0.500) F1: (train=0.000, test=0.000) FHALF: (train=0.000, test=0.000) RE: (train=0.000, test=0.000) total time=   0.0s
# [CV 12/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=15, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=StandardScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.091, test=0.118) AVG_PR: (train=0.091, test=0.118) BACC: (train=0.500, test=0.500) F1: (train=0.167, test=0.211) FHALF: (train=0.111, test=0.143) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 3/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=15, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=MinMaxScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.909, test=0.882) AVG_PR: (train=0.091, test=0.118) BACC: (train=0.500, test=0.500) F1: (train=0.000, test=0.000) FHALF: (train=0.000, test=0.000) RE: (train=0.000, test=0.000) total time=   0.0s
# [CV 20/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=15, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=MinMaxScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.896, test=0.938) AVG_PR: (train=0.104, test=0.062) BACC: (train=0.500, test=0.500) F1: (train=0.000, test=0.000) FHALF: (train=0.000, test=0.000) RE: (train=0.000, test=0.000) total time=   0.0s
# [CV 11/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=all, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=None, undersample=RandomUnderSampler(random_state=42); ACC: (train=0.909, test=0.882) AVG_PR: (train=0.274, test=0.583) BACC: (train=0.500, test=0.500) F1: (train=0.000, test=0.000) FHALF: (train=0.000, test=0.000) RE: (train=0.000, test=0.000) total time=   0.0s
# [CV 5/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=5, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=None, undersample=RandomUnderSampler(random_state=42); ACC: (train=0.104, test=0.062) AVG_PR: (train=0.104, test=0.062) BACC: (train=0.500, test=0.500) F1: (train=0.189, test=0.118) FHALF: (train=0.127, test=0.077) RE: (train=1.000, test=1.000) total time=   0.1s
# [CV 22/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=5, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=None, undersample=RandomUnderSampler(random_state=42); ACC: (train=0.091, test=0.118) AVG_PR: (train=0.091, test=0.118) BACC: (train=0.500, test=0.500) F1: (train=0.167, test=0.211) FHALF: (train=0.111, test=0.143) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 2/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=5, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=StandardScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.091, test=0.118) AVG_PR: (train=0.091, test=0.118) BACC: (train=0.500, test=0.500) F1: (train=0.167, test=0.211) FHALF: (train=0.111, test=0.143) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 11/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=5, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=StandardScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.091, test=0.118) AVG_PR: (train=0.091, test=0.118) BACC: (train=0.500, test=0.500) F1: (train=0.167, test=0.211) FHALF: (train=0.111, test=0.143) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 4/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=5, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=MinMaxScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.896, test=0.938) AVG_PR: (train=0.104, test=0.062) BACC: (train=0.500, test=0.500) F1: (train=0.000, test=0.000) FHALF: (train=0.000, test=0.000) RE: (train=0.000, test=0.000) total time=   0.0s
# [CV 20/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=5, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=MinMaxScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.896, test=0.938) AVG_PR: (train=0.104, test=0.062) BACC: (train=0.500, test=0.500) F1: (train=0.000, test=0.000) FHALF: (train=0.000, test=0.000) RE: (train=0.000, test=0.000) total time=   0.0s
# [CV 11/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=10, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=None, undersample=RandomUnderSampler(random_state=42); ACC: (train=0.091, test=0.118) AVG_PR: (train=0.091, test=0.118) BACC: (train=0.500, test=0.500) F1: (train=0.167, test=0.211) FHALF: (train=0.111, test=0.143) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 2/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=10, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=StandardScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.091, test=0.118) AVG_PR: (train=0.091, test=0.118) BACC: (train=0.500, test=0.500) F1: (train=0.167, test=0.211) FHALF: (train=0.111, test=0.143) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 18/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=10, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=StandardScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.091, test=0.118) AVG_PR: (train=0.091, test=0.118) BACC: (train=0.500, test=0.500) F1: (train=0.167, test=0.211) FHALF: (train=0.111, test=0.143) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 11/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=10, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=MinMaxScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.909, test=0.882) AVG_PR: (train=0.091, test=0.118) BACC: (train=0.500, test=0.500) F1: (train=0.000, test=0.000) FHALF: (train=0.000, test=0.000) RE: (train=0.000, test=0.000) total time=   0.0s
# [CV 1/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=15, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=None, undersample=RandomUnderSampler(random_state=42); ACC: (train=0.091, test=0.118) AVG_PR: (train=0.091, test=0.118) BACC: (train=0.500, test=0.500) F1: (train=0.167, test=0.211) FHALF: (train=0.111, test=0.143) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 16/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=15, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=None, undersample=RandomUnderSampler(random_state=42); ACC: (train=0.909, test=0.882) AVG_PR: (train=0.293, test=0.367) BACC: (train=0.500, test=0.500) F1: (train=0.000, test=0.000) FHALF: (train=0.000, test=0.000) RE: (train=0.000, test=0.000) total time=   0.0s
# [CV 7/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=15, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=StandardScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.091, test=0.118) AVG_PR: (train=0.091, test=0.118) BACC: (train=0.500, test=0.500) F1: (train=0.167, test=0.211) FHALF: (train=0.111, test=0.143) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 24/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=15, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=StandardScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.104, test=0.062) AVG_PR: (train=0.104, test=0.062) BACC: (train=0.500, test=0.500) F1: (train=0.189, test=0.118) FHALF: (train=0.127, test=0.077) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 15/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=15, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=MinMaxScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.896, test=0.938) AVG_PR: (train=0.104, test=0.062) BACC: (train=0.500, test=0.500) F1: (train=0.000, test=0.000) FHALF: (train=0.000, test=0.000) RE: (train=0.000, test=0.000) total time=   0.0s
# [CV 6/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=all, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=None, undersample=RandomUnderSampler(random_state=42); ACC: (train=0.909, test=0.882) AVG_PR: (train=0.255, test=0.333) BACC: (train=0.500, test=0.500) F1: (train=0.000, test=0.000) FHALF: (train=0.000, test=0.000) RE: (train=0.000, test=0.000) total time=   0.0s
# [CV 22/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=all, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=None, undersample=RandomUnderSampler(random_state=42); ACC: (train=0.909, test=0.882) AVG_PR: (train=0.285, test=0.333) BACC: (train=0.500, test=0.500) F1: (train=0.000, test=0.000) FHALF: (train=0.000, test=0.000) RE: (train=0.000, test=0.000) total time=   0.0s
# [CV 13/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=5, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=None, undersample=RandomUnderSampler(random_state=42); ACC: (train=0.091, test=0.118) AVG_PR: (train=0.091, test=0.118) BACC: (train=0.500, test=0.500) F1: (train=0.167, test=0.211) FHALF: (train=0.111, test=0.143) RE: (train=1.000, test=1.000) total time=   0.1s
# [CV 8/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=5, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=StandardScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.091, test=0.118) AVG_PR: (train=0.091, test=0.118) BACC: (train=0.500, test=0.500) F1: (train=0.167, test=0.211) FHALF: (train=0.111, test=0.143) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 22/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=5, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=StandardScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.091, test=0.118) AVG_PR: (train=0.091, test=0.118) BACC: (train=0.500, test=0.500) F1: (train=0.167, test=0.211) FHALF: (train=0.111, test=0.143) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 13/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=5, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=MinMaxScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.091, test=0.118) AVG_PR: (train=0.091, test=0.118) BACC: (train=0.500, test=0.500) F1: (train=0.167, test=0.211) FHALF: (train=0.111, test=0.143) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 3/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=10, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=None, undersample=RandomUnderSampler(random_state=42); ACC: (train=0.091, test=0.118) AVG_PR: (train=0.091, test=0.118) BACC: (train=0.500, test=0.500) F1: (train=0.167, test=0.211) FHALF: (train=0.111, test=0.143) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 19/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=10, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=None, undersample=RandomUnderSampler(random_state=42); ACC: (train=0.104, test=0.062) AVG_PR: (train=0.104, test=0.062) BACC: (train=0.500, test=0.500) F1: (train=0.189, test=0.118) FHALF: (train=0.127, test=0.077) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 8/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=10, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=StandardScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.091, test=0.118) AVG_PR: (train=0.091, test=0.118) BACC: (train=0.500, test=0.500) F1: (train=0.167, test=0.211) FHALF: (train=0.111, test=0.143) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 23/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=10, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=StandardScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.091, test=0.118) AVG_PR: (train=0.091, test=0.118) BACC: (train=0.500, test=0.500) F1: (train=0.167, test=0.211) FHALF: (train=0.111, test=0.143) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 14/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=10, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=MinMaxScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.896, test=0.938) AVG_PR: (train=0.104, test=0.062) BACC: (train=0.500, test=0.500) F1: (train=0.000, test=0.000) FHALF: (train=0.000, test=0.000) RE: (train=0.000, test=0.000) total time=   0.0s
# [CV 5/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=15, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=None, undersample=RandomUnderSampler(random_state=42); ACC: (train=0.104, test=0.062) AVG_PR: (train=0.104, test=0.062) BACC: (train=0.500, test=0.500) F1: (train=0.189, test=0.118) FHALF: (train=0.127, test=0.077) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 21/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=15, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=None, undersample=RandomUnderSampler(random_state=42); ACC: (train=0.091, test=0.118) AVG_PR: (train=0.091, test=0.118) BACC: (train=0.500, test=0.500) F1: (train=0.167, test=0.211) FHALF: (train=0.111, test=0.143) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 10/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=15, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=StandardScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.104, test=0.062) AVG_PR: (train=0.104, test=0.062) BACC: (train=0.500, test=0.500) F1: (train=0.189, test=0.118) FHALF: (train=0.127, test=0.077) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 1/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=15, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=MinMaxScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.909, test=0.882) AVG_PR: (train=0.091, test=0.118) BACC: (train=0.500, test=0.500) F1: (train=0.000, test=0.000) FHALF: (train=0.000, test=0.000) RE: (train=0.000, test=0.000) total time=   0.0s
# [CV 17/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=15, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=MinMaxScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.909, test=0.882) AVG_PR: (train=0.091, test=0.118) BACC: (train=0.500, test=0.500) F1: (train=0.000, test=0.000) FHALF: (train=0.000, test=0.000) RE: (train=0.000, test=0.000) total time=   0.0s
# [CV 8/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=all, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=None, undersample=RandomUnderSampler(random_state=42); ACC: (train=0.909, test=0.882) AVG_PR: (train=0.248, test=0.417) BACC: (train=0.500, test=0.500) F1: (train=0.000, test=0.000) FHALF: (train=0.000, test=0.000) RE: (train=0.000, test=0.000) total time=   0.0s
# [CV 24/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=all, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=None, undersample=RandomUnderSampler(random_state=42); ACC: (train=0.896, test=0.938) AVG_PR: (train=0.296, test=0.333) BACC: (train=0.500, test=0.500) F1: (train=0.000, test=0.000) FHALF: (train=0.000, test=0.000) RE: (train=0.000, test=0.000) total time=   0.0s
# [CV 15/25] END classifier__C=0.001, classifier__class_weight=None, classifier__penalty=l1, column_transform=None, feature_selection__k=all, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=StandardScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.104, test=0.062) AVG_PR: (train=0.104, test=0.062) BACC: (train=0.500, test=0.500) F1: (train=0.189, test=0.118) FHALF: (train=0.127, test=0.077) RE: (train=1.000, test=1.000) total time=   0.0s
# ...
# [CV 6/25] END classifier__C=0.1, classifier__class_weight=balanced, classifier__penalty=l1, column_transform=None, feature_selection__k=all, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=MinMaxScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.924, test=0.882) AVG_PR: (train=0.746, test=1.000) BACC: (train=0.958, test=0.933) F1: (train=0.706, test=0.667) FHALF: (train=0.600, test=0.556) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 22/25] END classifier__C=0.1, classifier__class_weight=balanced, classifier__penalty=l1, column_transform=None, feature_selection__k=all, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=MinMaxScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.955, test=0.882) AVG_PR: (train=0.842, test=0.750) BACC: (train=0.975, test=0.717) F1: (train=0.800, test=0.500) FHALF: (train=0.714, test=0.500) RE: (train=1.000, test=0.500) total time=   0.0s
# [CV 13/25] END classifier__C=0.1, classifier__class_weight=balanced, classifier__penalty=l2, column_transform=None, feature_selection__k=5, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=None, undersample=RandomUnderSampler(random_state=42); ACC: (train=0.939, test=0.882) AVG_PR: (train=0.816, test=0.625) BACC: (train=0.892, test=0.717) F1: (train=0.714, test=0.500) FHALF: (train=0.658, test=0.500) RE: (train=0.833, test=0.500) total time=   0.0s
# [CV 4/25] END classifier__C=0.1, classifier__class_weight=balanced, classifier__penalty=l2, column_transform=None, feature_selection__k=5, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=StandardScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.985, test=0.938) AVG_PR: (train=0.982, test=1.000) BACC: (train=0.992, test=0.967) F1: (train=0.933, test=0.667) FHALF: (train=0.897, test=0.556) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 20/25] END classifier__C=0.1, classifier__class_weight=balanced, classifier__penalty=l2, column_transform=None, feature_selection__k=5, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=StandardScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.985, test=0.938) AVG_PR: (train=0.962, test=1.000) BACC: (train=0.992, test=0.967) F1: (train=0.933, test=0.667) FHALF: (train=0.897, test=0.556) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 11/25] END classifier__C=0.1, classifier__class_weight=balanced, classifier__penalty=l2, column_transform=None, feature_selection__k=5, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=MinMaxScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.970, test=0.882) AVG_PR: (train=0.976, test=0.750) BACC: (train=0.983, test=0.717) F1: (train=0.857, test=0.500) FHALF: (train=0.789, test=0.500) RE: (train=1.000, test=0.500) total time=   0.0s
# [CV 2/25] END classifier__C=0.1, classifier__class_weight=balanced, classifier__penalty=l2, column_transform=None, feature_selection__k=10, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=None, undersample=RandomUnderSampler(random_state=42); ACC: (train=0.758, test=0.765) AVG_PR: (train=0.906, test=0.750) BACC: (train=0.867, test=0.867) F1: (train=0.429, test=0.500) FHALF: (train=0.319, test=0.385) RE: (train=1.000, test=1.000) total time=   0.1s
# [CV 19/25] END classifier__C=0.1, classifier__class_weight=balanced, classifier__penalty=l2, column_transform=None, feature_selection__k=10, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=None, undersample=RandomUnderSampler(random_state=42); ACC: (train=0.746, test=0.625) AVG_PR: (train=0.823, test=1.000) BACC: (train=0.858, test=0.800) F1: (train=0.452, test=0.250) FHALF: (train=0.340, test=0.172) RE: (train=1.000, test=1.000) total time=   0.1s
# [CV 19/25] END classifier__C=0.1, classifier__class_weight=balanced, classifier__penalty=l2, column_transform=None, feature_selection__k=10, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=StandardScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=1.000, test=1.000) AVG_PR: (train=1.000, test=1.000) BACC: (train=1.000, test=1.000) F1: (train=1.000, test=1.000) FHALF: (train=1.000, test=1.000) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 11/25] END classifier__C=0.1, classifier__class_weight=balanced, classifier__penalty=l2, column_transform=None, feature_selection__k=10, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=MinMaxScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.955, test=0.882) AVG_PR: (train=1.000, test=0.750) BACC: (train=0.975, test=0.717) F1: (train=0.800, test=0.500) FHALF: (train=0.714, test=0.500) RE: (train=1.000, test=0.500) total time=   0.0s
# [CV 2/25] END classifier__C=0.1, classifier__class_weight=balanced, classifier__penalty=l2, column_transform=None, feature_selection__k=15, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=None, undersample=RandomUnderSampler(random_state=42); ACC: (train=0.803, test=0.765) AVG_PR: (train=0.850, test=0.583) BACC: (train=0.892, test=0.867) F1: (train=0.480, test=0.500) FHALF: (train=0.366, test=0.385) RE: (train=1.000, test=1.000) total time=   0.1s
# [CV 19/25] END classifier__C=0.1, classifier__class_weight=balanced, classifier__penalty=l2, column_transform=None, feature_selection__k=15, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=None, undersample=RandomUnderSampler(random_state=42); ACC: (train=0.761, test=0.625) AVG_PR: (train=0.875, test=0.500) BACC: (train=0.867, test=0.800) F1: (train=0.467, test=0.250) FHALF: (train=0.354, test=0.172) RE: (train=1.000, test=1.000) total time=   0.1s
# [CV 11/25] END classifier__C=0.1, classifier__class_weight=balanced, classifier__penalty=l2, column_transform=None, feature_selection__k=15, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=StandardScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=1.000, test=0.941) AVG_PR: (train=1.000, test=1.000) BACC: (train=1.000, test=0.750) F1: (train=1.000, test=0.667) FHALF: (train=1.000, test=0.833) RE: (train=1.000, test=0.500) total time=   0.0s
# [CV 2/25] END classifier__C=0.1, classifier__class_weight=balanced, classifier__penalty=l2, column_transform=None, feature_selection__k=15, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=MinMaxScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.955, test=1.000) AVG_PR: (train=1.000, test=1.000) BACC: (train=0.975, test=1.000) F1: (train=0.800, test=1.000) FHALF: (train=0.714, test=1.000) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 16/25] END classifier__C=0.1, classifier__class_weight=balanced, classifier__penalty=l2, column_transform=None, feature_selection__k=15, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=MinMaxScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=1.000, test=1.000) AVG_PR: (train=1.000, test=1.000) BACC: (train=1.000, test=1.000) F1: (train=1.000, test=1.000) FHALF: (train=1.000, test=1.000) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 7/25] END classifier__C=0.1, classifier__class_weight=balanced, classifier__penalty=l2, column_transform=None, feature_selection__k=all, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=None, undersample=RandomUnderSampler(random_state=42); ACC: (train=0.742, test=0.824) AVG_PR: (train=0.220, test=0.417) BACC: (train=0.858, test=0.900) F1: (train=0.414, test=0.571) FHALF: (train=0.306, test=0.455) RE: (train=1.000, test=1.000) total time=   0.2s
# [CV 24/25] END classifier__C=0.1, classifier__class_weight=balanced, classifier__penalty=l2, column_transform=None, feature_selection__k=all, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=None, undersample=RandomUnderSampler(random_state=42); ACC: (train=0.791, test=0.625) AVG_PR: (train=0.268, test=0.250) BACC: (train=0.883, test=0.800) F1: (train=0.500, test=0.250) FHALF: (train=0.385, test=0.172) RE: (train=1.000, test=1.000) total time=   0.2s
# [CV 11/25] END classifier__C=0.1, classifier__class_weight=balanced, classifier__penalty=l2, column_transform=None, feature_selection__k=5, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=None, undersample=RandomUnderSampler(random_state=42); ACC: (train=0.955, test=0.941) AVG_PR: (train=0.741, test=1.000) BACC: (train=0.825, test=0.750) F1: (train=0.727, test=0.667) FHALF: (train=0.769, test=0.833) RE: (train=0.667, test=0.500) total time=   0.0s
# [CV 2/25] END classifier__C=0.1, classifier__class_weight=balanced, classifier__penalty=l2, column_transform=None, feature_selection__k=5, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=StandardScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.970, test=1.000) AVG_PR: (train=0.915, test=1.000) BACC: (train=0.983, test=1.000) F1: (train=0.857, test=1.000) FHALF: (train=0.789, test=1.000) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 18/25] END classifier__C=0.1, classifier__class_weight=balanced, classifier__penalty=l2, column_transform=None, feature_selection__k=5, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=StandardScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.985, test=0.941) AVG_PR: (train=1.000, test=1.000) BACC: (train=0.992, test=0.967) F1: (train=0.923, test=0.800) FHALF: (train=0.882, test=0.714) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 9/25] END classifier__C=0.1, classifier__class_weight=balanced, classifier__penalty=l2, column_transform=None, feature_selection__k=5, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=MinMaxScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.881, test=0.875) AVG_PR: (train=0.903, test=1.000) BACC: (train=0.933, test=0.933) F1: (train=0.636, test=0.500) FHALF: (train=0.522, test=0.385) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 23/25] END classifier__C=0.1, classifier__class_weight=balanced, classifier__penalty=l2, column_transform=None, feature_selection__k=5, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=MinMaxScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.939, test=1.000) AVG_PR: (train=0.896, test=1.000) BACC: (train=0.892, test=1.000) F1: (train=0.714, test=1.000) FHALF: (train=0.658, test=1.000) RE: (train=0.833, test=1.000) total time=   0.0s
# [CV 14/25] END classifier__C=0.1, classifier__class_weight=balanced, classifier__penalty=l2, column_transform=None, feature_selection__k=10, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=None, undersample=RandomUnderSampler(random_state=42); ACC: (train=0.836, test=0.812) AVG_PR: (train=0.921, test=1.000) BACC: (train=0.908, test=0.900) F1: (train=0.560, test=0.400) FHALF: (train=0.443, test=0.294) RE: (train=1.000, test=1.000) total time=   0.1s
# [CV 6/25] END classifier__C=0.1, classifier__class_weight=balanced, classifier__penalty=l2, column_transform=None, feature_selection__k=10, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=StandardScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=1.000, test=1.000) AVG_PR: (train=1.000, test=1.000) BACC: (train=1.000, test=1.000) F1: (train=1.000, test=1.000) FHALF: (train=1.000, test=1.000) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 16/25] END classifier__C=0.1, classifier__class_weight=balanced, classifier__penalty=l2, column_transform=None, feature_selection__k=10, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=StandardScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=1.000, test=1.000) AVG_PR: (train=1.000, test=1.000) BACC: (train=1.000, test=1.000) F1: (train=1.000, test=1.000) FHALF: (train=1.000, test=1.000) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 7/25] END classifier__C=0.1, classifier__class_weight=balanced, classifier__penalty=l2, column_transform=None, feature_selection__k=10, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=MinMaxScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.939, test=1.000) AVG_PR: (train=0.924, test=1.000) BACC: (train=0.892, test=1.000) F1: (train=0.714, test=1.000) FHALF: (train=0.658, test=1.000) RE: (train=0.833, test=1.000) total time=   0.0s
# [CV 23/25] END classifier__C=0.1, classifier__class_weight=balanced, classifier__penalty=l2, column_transform=None, feature_selection__k=10, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=MinMaxScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.939, test=1.000) AVG_PR: (train=0.910, test=1.000) BACC: (train=0.892, test=1.000) F1: (train=0.714, test=1.000) FHALF: (train=0.658, test=1.000) RE: (train=0.833, test=1.000) total time=   0.0s
# [CV 14/25] END classifier__C=0.1, classifier__class_weight=balanced, classifier__penalty=l2, column_transform=None, feature_selection__k=15, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=None, undersample=RandomUnderSampler(random_state=42); ACC: (train=0.821, test=0.750) AVG_PR: (train=0.937, test=1.000) BACC: (train=0.900, test=0.867) F1: (train=0.538, test=0.333) FHALF: (train=0.422, test=0.238) RE: (train=1.000, test=1.000) total time=   0.1s
# [CV 5/25] END classifier__C=0.1, classifier__class_weight=balanced, classifier__penalty=l2, column_transform=None, feature_selection__k=15, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=StandardScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=1.000, test=1.000) AVG_PR: (train=1.000, test=1.000) BACC: (train=1.000, test=1.000) F1: (train=1.000, test=1.000) FHALF: (train=1.000, test=1.000) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 18/25] END classifier__C=0.1, classifier__class_weight=balanced, classifier__penalty=l2, column_transform=None, feature_selection__k=15, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=StandardScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=1.000, test=1.000) AVG_PR: (train=1.000, test=1.000) BACC: (train=1.000, test=1.000) F1: (train=1.000, test=1.000) FHALF: (train=1.000, test=1.000) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 8/25] END classifier__C=0.1, classifier__class_weight=balanced, classifier__penalty=l2, column_transform=None, feature_selection__k=15, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=MinMaxScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.985, test=0.882) AVG_PR: (train=1.000, test=0.833) BACC: (train=0.992, test=0.717) F1: (train=0.923, test=0.500) FHALF: (train=0.882, test=0.500) RE: (train=1.000, test=0.500) total time=   0.0s
# [CV 24/25] END classifier__C=0.1, classifier__class_weight=balanced, classifier__penalty=l2, column_transform=None, feature_selection__k=15, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=MinMaxScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=0.985, test=1.000) AVG_PR: (train=1.000, test=1.000) BACC: (train=0.992, test=1.000) F1: (train=0.933, test=1.000) FHALF: (train=0.897, test=1.000) RE: (train=1.000, test=1.000) total time=   0.0s
# [CV 15/25] END classifier__C=0.1, classifier__class_weight=balanced, classifier__penalty=l2, column_transform=None, feature_selection__k=all, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=None, undersample=RandomUnderSampler(random_state=42); ACC: (train=0.731, test=0.875) AVG_PR: (train=0.261, test=0.333) BACC: (train=0.850, test=0.933) F1: (train=0.438, test=0.500) FHALF: (train=0.327, test=0.385) RE: (train=1.000, test=1.000) total time=   0.3s
# [CV 18/25] END classifier__C=0.1, classifier__class_weight=balanced, classifier__penalty=l2, column_transform=None, feature_selection__k=all, oversample=SMOTE(k_neighbors=3, random_state=42), scaler=StandardScaler(), undersample=RandomUnderSampler(random_state=42); ACC: (train=1.000, test=1.000) AVG_PR: (train=1.000, test=1.000) BACC: (train=1.000, test=1.000) F1: (train=1.000, test=1.000) FHALF: (train=1.000, test=1.000) RE: (train=1.000, test=1.000) total time=   0.0s

# %% [markdown]
# ## XGBoost

# %%
oof_xgb_prauc = binary_xgboost_gridsearch(ct, X_train, y_train_binary_oof, 'AVG_PR')
oof_xgb_prauc_model = oof_xgb_prauc.best_estimator_
save_model(oof_xgb_prauc_model, "models", "oof_xgb_prauc.pkl")

oof_xgb_fhalf = binary_xgboost_gridsearch(ct, X_train, y_train_binary_oof, 'FHALF')
oof_xgb_fhalf_model = oof_xgb_fhalf.best_estimator_
save_model(oof_xgb_fhalf_model, "models", "oof_xgb_fhalf.pkl")

evaluate_model(oof_xgb_prauc_model, X_train, X_test, y_train_binary_oof, y_test_binary_oof)
evaluate_model(oof_xgb_fhalf_model, X_train, X_test, y_train_binary_oof, y_test_binary_oof)

# %% [markdown]
# # AGG Binary Classifier

# %%
y_train_binary_agg = np.where(y_train == 'agg', 1, 0)
y_test_binary_agg = np.where(y_test == 'agg', 1, 0)

# %% [markdown]
# ## Logistic Regression

# %%
agg_logreg_prauc = binary_logreg_gridsearch(ct, X_train, y_train_binary_agg, 'AVG_PR')
agg_logreg_prauc_model = agg_logreg_prauc.best_estimator_
save_model(agg_logreg_prauc_model, "models", "agg_logreg_prauc.pkl")

agg_logreg_fhalf = binary_logreg_gridsearch(ct, X_train, y_train_binary_agg, 'FHALF')
agg_logreg_fhalf_model = agg_logreg_fhalf.best_estimator_
save_model(agg_logreg_fhalf_model, "models", "agg_logreg_fhalf.pkl")

evaluate_model(agg_logreg_prauc_model, X_train, X_test, y_train_binary_agg, y_test_binary_agg)
evaluate_model(agg_logreg_fhalf_model, X_train, X_test, y_train_binary_agg, y_test_binary_agg)

# %% [markdown]
# ## XGBoost

# %%
agg_xgb_prauc = binary_xgboost_gridsearch(ct, X_train, y_train_binary_agg, 'AVG_PR')
agg_xgb_prauc_model = agg_xgb_prauc.best_estimator_
save_model(agg_xgb_prauc_model, "models", "agg_xgb_prauc.pkl")

agg_xgb_fhalf = binary_xgboost_gridsearch(ct, X_train, y_train_binary_agg, 'FHALF')
agg_xgb_fhalf_model = agg_xgb_fhalf.best_estimator_
save_model(agg_xgb_fhalf_model, "models", "agg_xgb_fhalf.pkl")

evaluate_model(agg_xgb_prauc_model, X_train, X_test, y_train_binary, y_test_binary)
evaluate_model(agg_xgb_fhalf_model, X_train, X_test, y_train_binary, y_test_binary)

# %% [markdown]
# # Cell Multiclass Classifier

# %%
X_train_cell = X_train[(y_train == 'plt') | (y_train == 'wbc') | (y_train == 'rbc')]
y_train_cell = y_train[(y_train == 'plt') | (y_train == 'wbc') | (y_train == 'rbc')]
X_test_cell = X_test[(y_test == 'plt') | (y_test == 'wbc') | (y_test == 'rbc')]
y_test_cell = y_test[(y_test == 'plt') | (y_test == 'wbc') | (y_test == 'rbc')]

# %% [markdown]
# ## Logistic Regression

# %%
cell_logreg_f1macro = multiclass_logreg_gridsearch(ct, X_train_cell, y_train_cell, 'F1_MACRO')
cell_logreg_f1macro_model = cell_logreg_f1macro.best_estimator_
save_model(cell_logreg_f1macro_model, "models", "cell_logreg_f1macro.pkl")

# %% [markdown]
# ## XGBoost

# %%
cell_xgb_f1macro = multiclass_xgboost_gridsearch(ct, X_train_cell, y_train_cell, 'F1_MACRO')
cell_xgb_f1macro_model = cell_xgb_f1macro.best_estimator_
save_model(cell_xgb_f1macro_model, "models", "cell_xgb_f1macro.pkl")
